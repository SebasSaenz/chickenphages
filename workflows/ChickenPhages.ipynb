# %% [markdown]
# # Run FIRST

# %%
### VARIABLES ###

#python variables
REF_GENS = {
    'Chicken': '/beegfs/work/graaf20/Databases/Ref_gens/Chicken/GCA_024206055.2_GGswu_genomic.fna',
    'Corn': '/beegfs/work/graaf20/Databases/Ref_gens/Corn/GCA_902167145.1_Zm-B73-REFERENCE-NAM-5.0_genomic.fna'
}


#shared between bash and python
VARS = (
    'WS=/beegfs/work/graaf20/ChickenPhages\n'
    'DB=/beegfs/work/graaf20/Databases/\n'
    'DATA=Data\n'
    'RES=Results\n'
    'ASS=Results/Assemlies_MegaHit\n'
    'MH=MegaHit_temp\n'
    'FIG=Figures\n'
    'LOGS=Logs\n'
    'RR=Raw_reads\n'
    'CR=Clean_reads\n'
)

#METADATA = pd.read_csv('metadata.tsv', sep='\t', index_col=0)

CONDA = '$HOME/miniconda3/etc/profile.d/conda.sh'


##################### DO NOT CHANGE ################################
import pandas as pd
import numpy as np
import os

#extract bash variables for python
for var in VARS.strip().split('\n'):
    vars()[var.split('=')[0]]=var.split('=')[1]

# !mkdir -p $WS/$CR $WS/$LOGS $WS/$TABS $WS/$RES $WS/$FIG
    
#Binac function
params = '''
#PBS -l nodes={nodes}:ppn={ppn}
#PBS -l walltime={time}
#PBS -l mem={mem}gb
#PBS -N {name}.sh
#PBS -o {logdir}
#PBS -e {logdir}
#PBS -q {queue}
#PBS -S /bin/bash
export TMPDIR=$TMPDIR
''' 

source = f'source {CONDA}'

COMM = '#Custom variables and commands\n{todo}'
STRING = '\n'.join([params, source, VARS, COMM])

# binac function that will submit the job to server
def binac(nodes=1, ppn=1, time='00:15:00', mem=2, name='myjob', logdir=WS,
          queue='tiny', todo='echo "Command"', STRING=STRING, ):
    text = STRING
    if '{nodes}' in STRING:
        text = STRING.format(nodes=nodes, ppn=ppn, time=time, logdir=f'{WS}/{logdir}',
               mem=mem, name=name, queue=queue, todo=todo)
    script = f'{WS}/{logdir}/{name}.sh'
    # !mkdir -p $WS/$logdir
    with open(script, "w") as text_file:
        text_file.write(text)
    # !chmod +x $script
    # !qsub $script
    
###############################################################################################

bad = ['SRR5280393', 'ERR2241736', 'ERR2241917', 'SRR12730717', 'SRR7683044',
       'SRR7457769', 'SRR9113694', 'ERR2241801', 'SRR17836573', 'SRR7685268', 
       'SRR9113697', 'SRR9113700', 'SRR5280759', 'SRR17836591', 'SRR7457773', 
       'SRR7683048', 'ERR2241740', 'ERR2241741', 'SRR17836604', 'SRR7683050', 
       'SRR7457774', 'ERR2241809', 'SRR5282097', 'SRR12730726', 'SRR7683052',
       'ERR2241763', 'ERR2241943', 'SRR7685282', 'SRR17836559', 'SRR7457783',
       'ERR2241850', 'ERR2241735', 'ERR2241764', 'SRR12730743', 'SRR7457734', 
       'ERR2241631', 'SRR7683056', 'SRR7457738', 'SRR7683059',  'ERR2241635',
       'SRR7457741', 'ERR2241791', 'ERR2241795', 'SRR7457745',  'ERR2241689', 
       'SRR7685255', 'SRR7685256', 'ERR2241698', 'SRR7457755', ] 

# get batches and locals
df = pd.read_csv(f'{WS}/Data/MAGs_dataset_complete.csv', index_col=0, na_filter = False)
df.BioProject = df.BioProject.str.replace('NA', 'Local')
#locs = df.loc[df.BioProject == 'Local', 'Run'].unique().tolist()
#sras = df.loc[df.BioProject != 'Local', 'Run'].unique().tolist()
sras = df.loc[~df.Run.isin(bad), 'Run'].unique().tolist()
b = 30
batches = {f'batch{i+1}-{i+b}': sras[i:i + b] for i in range(0, len(sras), b)}

# Create list of file indexes to access it later
cleaning = !rm -r $WS/*/*/*/.ipynb_ch* $WS/*/*/.ipynb_ch* $WS/*/.ipynb_ch* $WS/.ipynb_ch*

raws = []
if os.path.exists(f'{WS}/{RR}'): 
    raws = [f.rsplit('_', 1)[0] for f in os.listdir(f'{WS}/{RR}') if '.gz' in f]
    raws = sorted(list(set(raws)))
    print('Number of raw samples: ', len(raws))

cleans = []
if os.path.exists(f'{WS}/{CR}'): 
    cleans = [f.rsplit('_', 1)[0] for f in os.listdir(f'{WS}/{CR}') if '.gz' in f]
    cleans = sorted(list(set(cleans)))
    print('Number of clean samples: ', len(cleans))
    
asses = []
if os.path.exists(f'{WS}/{ASS}'): 
    asses = [f.rsplit('.', 1)[0] for f in os.listdir(f'{WS}/{ASS}') if '.fa' in f]
    asses = sorted(list(set(asses)))
    print('Number of assembles: ', len(asses))
    
permissions = !chmod +rwx $BIN/*
# Out:
# Number of raw samples:  0
# Number of clean samples:  1080
# Number of assembles:  1446

# %%
len(sras)
# Out:
# 1515

# %%
batches
# Out:
# {'batch1-30': ['SRR12730711',
#   'SRR12730712',
#   'SRR12730713',
#   'SRR12730714',
#   'SRR12730715',
#   'SRR12730716',
#   'SRR12730718',
#   'SRR12730719',
#   'SRR12730720',
#   'SRR12730721',
#   'SRR12730722',
#   'SRR12730723',
#   'SRR12730724',
#   'SRR12730725',
#   'SRR12730727',
#   'SRR12730728',
#   'SRR12730729',
#   'SRR12730730',
#   'SRR12730731',
#   'SRR12730732',
#   'SRR12730733',
#   'SRR12730734',
#   'SRR12730735',
#   'SRR12730736',
#   'SRR12730737',
#   'SRR12730738',
#   'SRR12730739',
#   'SRR12730740',
#   'SRR12730741',
#   'SRR12730742'],
#  'batch31-60': ['SRR12730744',
#   'SRR12730745',
#   'SRR12730746',
#   'SRR12730747',
#   'SRR12730748',
#   'SRR12730749',
#   'SRR12730750',
#   'SRR8840688',
#   'SRR8840689',
#   'SRR8840690',
#   'SRR8840691',
#   'SRR8840692',
#   'SRR8840693',
#   'SRR8840694',
#   'SRR6323082',
#   'SRR6323083',
#   'SRR6323084',
#   'SRR6323085',
#   'SRR6323086',
#   'SRR6323087',
#   'SRR6323088',
#   'SRR6323089',
#   'SRR6323090',
#   'SRR6323091',
#   'SRR6323092',
#   'SRR6323093',
#   'SRR6323094',
#   'SRR6323095',
#   'SRR6323096',
#   'SRR6323097'],
#  'batch61-90': ['SRR6323098',
#   'SRR6323099',
#   'SRR6323100',
#   'SRR6323101',
#   'SRR6323102',
#   'SRR6323103',
#   'SRR6323104',
#   'SRR6323105',
#   'SRR6323106',
#   'SRR6323107',
#   'SRR6323108',
#   'SRR6323109',
#   'SRR7457761',
#   'SRR7457762',
#   'SRR7457763',
#   'SRR7457764',
#   'SRR7457765',
#   'SRR7457766'],
#  'batch631-660': ['SRR7457767',
#   'SRR7457768',
#   'SRR7457770',
#   'SRR7457771',
#   'SRR7457772',
#   'SRR7457775',
#   'SRR7457776',
#   'SRR7457777',
#   'SRR7457778',
#   'SRR7457779',
#   'SRR7457780',
#   'SRR7457781',
#   'SRR7457782',
#   'ERR2241628',
#   'ERR2241632',
#   'ERR2241634',
#   'ERR2241637',
#   'ERR2241639',
#   'ERR2241641',
#   'ERR2241643',
#   'ERR2241645',
#   'ERR2241647',
#   'ERR2241649',
#   'ERR2241651',
#   'ERR2241653',
#   'ERR2241655',
#   'ERR2241657',
#   'ERR2241659',
#   'ERR2241662',
#   'ERR2241664'],
#  'batch661-690': ['ERR2241665',
#   'ERR2241686',
#   'ERR2241687',
#   'ERR2241688',
#   'ERR2241690',
#   'ERR2241691',
#   'ERR2241692',
#   'ERR2241693',
#   'ERR2241694',
#   'ERR2241695',
#   'ERR2241696',
#   'ERR2241697',
#   'ERR2241699',
#   'ERR2241700',
#   'ERR2241701',
#   'ERR2241702',
#   'ERR2241703',
#   'ERR2241704',
#   'ERR2241725',
#   'ERR2241726',
#   'ERR2241727',
#   'ERR2241728',
#   'ERR2241729',
#   'ERR2241730',
#   'ERR2241731',
#   'ERR2241732',
#   'ERR2241733',
#   'ERR2241734',
#   'ERR2241737',
#   'ERR2241738'],
#  'batch691-720': ['ERR2241739',
#   'ERR2241742',
#   'ERR2241743',
#   'ERR2241744',
#   'ERR2241747',
#   'ERR2241748',
#   'ERR2241749',
#   'ERR2241750',
#   'ERR2241752',
#   'ERR2241753',
#   'ERR2241754',
#   'ERR2241755',
#   'ERR2241756',
#   'ERR2241758',
#   'ERR2241759',
#   'ERR2241760',
#   'ERR2241761',
#   'ERR2241762',
#   'ERR2241765',
#   'ERR2241770',
#   'ERR2241783',
#   'ERR2241784',
#   'ERR2241788',
#   'ERR2241790',
#   'ERR2241794',
#   'ERR2241798',
#   'ERR2241799',
#   'ERR2241802',
#   'ERR2241803',
#   'ERR2241805'],
#  'batch721-750': ['ERR2241806',
#   'ERR2241807',
#   'ERR2241808',
#   'ERR2241815',
#   'ERR2241818',
#   'ERR2241819',
#   'ERR2241823',
#   'ERR2241824',
#   'ERR2241828',
#   'ERR2241848',
#   'ERR2241849',
#   'ERR2241851',
#   'ERR2241852',
#   'ERR2241853',
#   'ERR2241854',
#   'ERR2241855',
#   'ERR2241856',
#   'ERR2241857',
#   'ERR2241858',
#   'ERR2241859',
#   'ERR2241860',
#   'ERR2241861',
#   'ERR2241862',
#   'ERR2241863',
#   'ERR2241864',
#   'ERR2241865',
#   'ERR2241866',
#   'ERR2241887',
#   'ERR2241888',
#   'ERR2241889'],
#  'batch751-780': ['ERR2241890',
#   'ERR2241891',
#   'ERR2241892',
#   'ERR2241893',
#   'ERR2241894',
#   'ERR2241895',
#   'ERR2241896',
#   'ERR2241897',
#   'ERR2241898',
#   'ERR2241899',
#   'ERR2241900',
#   'ERR2241901',
#   'ERR2241902',
#   'ERR2241903',
#   'ERR2241904',
#   'ERR2241905',
#   'ERR2241906',
#   'ERR2241907',
#   'ERR2241909',
#   'ERR2241911',
#   'ERR2241913',
#   'ERR2241915',
#   'ERR2241919',
#   'ERR2241921',
#   'ERR2241923',
#   'ERR2241925',
#   'ERR2241927',
#   'ERR2241929',
#   'ERR2241931',
#   'ERR2241933'],
#  'batch781-810': ['ERR2241935',
#   'ERR2241937',
#   'ERR2241939',
#   'ERR2241941',
#   'ERR2241945',
#   'ERR2241950',
#   'ERR2241952',
#   'ERR2241953',
#   'ERR2241954',
#   'ERR2241955',
#   'ERR2241956',
#   'ERR2241957',
#   'ERR2241971',
#   'ERR2241972',
#   'ERR2241977',
#   'ERR2241978',
#   'ERR2241979',
#   'ERR2241980',
#   'ERR2241981',
#   'ERR2241982',
#   'ERR2241983',
#   'ERR2241984',
#   'ERR2241985',
#   'ERR2241986',
#   'ERR2245455',
#   'SRR4096731',
#   'SRR4096732',
#   'SRR4096733',
#   'SRR4096734',
#   'SRR4096735'],
#  'batch811-840': ['SRR4096736',
#   'SRR4096737',
#   'SRR4096738',
#   'SRR4096739',
#   'SRR4096740',
#   'SRR4096741',
#   'SRR4096742',
#   'SRR4096743',
#   'SRR4096744',
#   'SRR4096745',
#   'SRR4096746',
#   'SRR4096747',
#   'SRR4096748',
#   'SRR4096749',
#   'SRR4096750',
#   'SRR4096751',
#   'SRR4096752',
#   'SRR4096753',
#   'SRR4096754',
#   'SRR4096755',
#   'SRR4096756',
#   'SRR4096757',
#   'SRR4096758',
#   'SRR4096759',
#   'SRR2134638',
#   'SRR2134645',
#   'SRR2134650',
#   'SRR2134673',
#   'SRR5280289',
#   'SRR5280514'],
#  'batch841-870': ['SRR5280757',
#   'SRR5280758',
#   'SRR5281813',
#   'SRR5281814',
#   'SRR5281815',
#   'SRR5282096',
#   'SRR5282098',
#   'SRR10897114',
#   'SRR10897115',
#   'SRR10897116',
#   'SRR10897117',
#   'SRR17836558',
#   'SRR17836560',
#   'SRR17836561',
#   'SRR17836562',
#   'SRR17836563',
#   'SRR17836564',
#   'SRR17836565',
#   'SRR17836566',
#   'SRR17836567',
#   'SRR17836568',
#   'SRR17836569',
#   'SRR17836570',
#   'SRR17836571',
#   'SRR17836572',
#   'SRR17836574',
#   'SRR17836575',
#   'SRR17836576',
#   'SRR17836577',
#   'SRR17836578'],
#  'batch871-900': ['SRR17836579',
#   'SRR17836580',
#   'SRR17836581',
#   'SRR17836582',
#   'SRR17836583',
#   'SRR17836584',
#   'SRR17836585',
#   'SRR17836586',
#   'SRR17836587',
#   'SRR17836588',
#   'SRR17836589',
#   'SRR17836590',
#   'SRR17836592',
#   'SRR17836593',
#   'SRR17836594',
#   'SRR17836595',
#   'SRR17836596',
#   'SRR17836597',
#   'SRR17836598',
#   'SRR17836599',
#   'SRR17836600',
#   'SRR17836601',
#   'SRR17836602',
#   'SRR17836603',
#   'SRR17836605',
#   'SRR17836606',
#   'SRR17836607',
#   'SRR17836608',
#   'SRR17836609',
#  'batch1051-1080': ['UHO76',
#   'UHO77',
#   'UHO78',
#   'UHO79',
#   'UHO80',
#   'UHO81',
#   'UHO82',
#   'UHO83',
#   'UHO84',
#   'UHO85',
#   'UHO86',
#   'UHO87',
#   'UHO88',
#   'UHO89',
#   'UHO90',
#   'UHO91',
#   'UHO92',
#   'UHO93',
#   'UHO94',
#   'UHO95',
#   'UHO96',
#   'UHO97',
#   'UHO98',
#   'UHO99',
#   'UHO100',
#   'UHO101',
#   'UHO102',
#   'UHO103',
#   'UHO104',
#   'UHO105'],
#  'batch1081-1110': ['UHO106',
#   'UHO107',
#   'UHO108',
#   'UHO109',
#   'UHO110',
#   'UHO111',
#   'UHO112',
#   'UHO113',
#   'UHO114',
#   'UHO115',
#   'UHO116',
#   'UHO117',
#   'UHO118',
#   'UHO119',
#   'UHO120',
#   'UHO121',
#   'UHO122',
#   'UHO123',
#   'UHO124',
#   'UHO125',
#   'UHO126',
#   'UHO127',
#   'UHO128',
#   'UHO129',
#   'UHO130',
#   'UHO131',
#   'UHO132',
#   'UHO133',
#   'UHO134',
#   'UHO135'],
#  'batch1111-1140': ['UHO136',
#   'UHO137',
#   'UHO138',
#   'UHO139',
#   'UHO140',
#   'UHO141',
#   'UHO142',
#   'UHO143',
#   'UHO144',
#   'UHO145',
#   'UHO146',
#   'UHO147',
#   'UHO148',
#   'UHO149',
#   'UHO150',
#   'UHO151',
#   'UHO152',
#   'UHO153',
#   'UHO154',
#   'UHO155',
#   'UHO156',
#   'UHO157',
#   'UHO158',
#   'UHO159',
#   'UHO160',
#   'UHO161',
#   'UHO162',
#   'UHO163',
#   'UHO164',
#   'UHO165'],
#  'batch1141-1170': ['UHO166',
#   'UHO167',
#   'UHO168',
#   'UHO169',
#   'UHO170',
#   'UHO171',
#   'UHO172',
#   'UHO173',
#   'UHO174',
#   'UHO175',
#   'UHO176',
#   'UHO177',
#   'UHO178',
#   'UHO179',
#   'UHO180',
#   'UHO181',
#   'UHO182',
#   'UHO183',
#   'UHO184',
#   'UHO185',
#   'UHO186',
#   'UHO187',
#   'UHO188',
#   'UHO189',
#   'UHO190',
#   'UHO191',
#   'UHO192',
#   'UHO193',
#   'UHO194',
#   'UHO195'],
#  'batch1171-1200': ['UHO196',
#   'UHO197',
#   'UHO198',
#   'UHO199',
#   'UHO200',
#   'UHO201',
#   'UHO202',
#   'UHO203',
#   'UHO204',
#   'UHO205',
#   'UHO206',
#   'UHO207',
#   'UHO208',
#   'UHO209',
#   'UHO210',
#   'UHO211',
#   'UHO212',
#   'UHO213',
#   'UHO214',
#   'UHO215',
#   'UHO216',
#   'UHO217',
#   'UHO218',
#   'UHO219',
#   'UHO220',
#   'UHO221',
#   'UHO222',
#   'UHO223',
#   'UHO224',
#   'UHO225'],
#  'batch1201-1230': ['UHO226',
#   'UHO227',
#   'UHO228',
#   'UHO229',
#   'UHO230',
#   'UHO231',
#   'UHO232',
#   'UHO233',
#   'UHO234',
#   'UHO235',
#   'UHO236',
#   'UHO237',
#   'UHO238',
#   'UHO239',
#   'UHO240',
#   'UHO241',
#   'UHO242',
#   'UHO243',
#   'UHO244',
#   'UHO245',
#   'UHO246',
#   'UHO247',
#   'UHO248',
#   'UHO249',
#   'UHO250',
#   'UHO251',
#   'UHO252',
#   'UHO253',
#   'UHO254',
#   'UHO255'],
#  'batch1231-1260': ['UHO256',
#   'UHO257',
#   'UHO258',
#   'UHO259',
#   'UHO260',
#   'UHO261',
#   'UHO262',
#   'UHO263',
#   'UHO264',
#   'UHO265',
#   'UHO266',
#   'UHO267',
#   'UHO268',
#   'UHO269',
#   'UHO270',
#   'UHO271',
#   'UHO272',
#   'UHO273',
#   'UHO274',
#   'UHO275',
#   'UHO276',
#   'UHO277',
#   'UHO278',
#   'UHO279',
#   'UHO280',
#   'UHO281',
#   'UHO282',
#   'UHO283',
#   'UHO284',
#   'UHO285'],
#  'batch1261-1290': ['UHO286',
#   'UHO287',
#   'UHO288',
#   'UHO289',
#   'UHO290',
#   'UHO291',
#   'UHO292',
#   'UHO293',
#   'UHO294',
#   'UHO295',
#   'UHO296',
#   'UHO297',
#   'UHO298',
#   'UHO299',
#   'UHO300',
#   'UHO301',
#   'UHO302',
#   'UHO303',
#   'UHO304',
#   'UHO305',
#   'UHO306',
#   'UHO307',
#   'UHO308',
#   'UHO309',
#   'UHO310',
#   'UHO311',
#   'UHO312',
#   'UHO313',
#   'UHO314',
#   'UHO315'],
#  'batch1291-1320': ['UHO316',
#   'UHO317',
#   'UHO318',
#   'UHO319',
#   'UHO320',
#   'UHO321',
#   'UHO322',
#   'UHO323',
#   'UHO324',
#   'UHO325',
#   'UHO326',
#   'UHO327',
#   'UHO328',
#   'UHO329',
#   'UHO330',
#   'UHO331',
#   'UHO332',
#   'UHO333',
#   'UHO334',
#   'UHO335',
#   'UHO336',
#   'UHO337',
#   'UHO338',
#   'UHO339',
#   'UHO340',
#   'UHO341',
#   'UHO342',
#   'UHO343',
#   'UHO344',
#   'UHO345'],
#  'batch1321-1350': ['UHO346',
#   'UHO347',
#   'UHO348',
#   'UHO349',
#   'UHO350',
#   'UHO351',
#   'UHO352',
#   'UHO353',
#   'UHO354',
#   'UHO355',
#   'UHO356',
#   'UHO357',
#   'UHO358',
#   'UHO359',
#   'UHO360',
#   'UHO361',
#   'UHO362',
#   'UHO363',
#   'UHO364',
#   'UHO365',
#   'UHO366',
#   'UHO367',
#   'UHO368',
#   'UHO369',
#   'UHO370',
#   'UHO371',
#   'UHO372',
#   'UHO373',
#   'UHO374',
#   'UHO375'],
#  'batch1351-1380': ['UHO376',
#   'UHO377',
#   'UHO378',
#   'UHO379',
#   'UHO380',
#   'UHO381',
#   'UHO382',
#   'UHO383',
#   'UHO384',
#   'UHO385',
#   'UHO386',
#   'UHO387',
#   'UHO388',
#   'UHO389',
#   'UHO390',
#   'UHO391',
#   'UHO392',
#   'UHO393',
#   'UHO394',
#   'UHO395',
#   'UHO396',
#   'UHO397',
#   'UHO398',
#   'UHO399',
#   'UHO400',
#   'UHO401',
#   'UHO402',
#   'UHO403',
#   'UHO404',
#   'UHO405'],
#  'batch1381-1410': ['UHO406',
#   'UHO407',
#   'UHO408',
#   'UHO409',
#   'UHO410',
#   'UHO411',
#   'UHO412',
#   'UHO413',
#   'UHO414',
#   'UHO415',
#   'UHO416',
#   'UHO417',
#   'UHO418',
#   'UHO419',
#   'UHO420',
#   'UHO421',
#   'UHO422',
#   'UHO423',
#   'UHO424',
#   'UHO425',
#   'UHO426',
#   'UHO427',
#   'UHO428',
#   'UHO429',
#   'UHO430',
#   'UHO431',
#   'UHO432',
#   'UHO433',
#   'UHO434',
#   'UHO435'],
#  'batch1411-1440': ['LH1_241',
#   'LH1_242',
#   'LH1_243',
#   'LH1_244',
#   'LH1_245',
#   'LH1_246',
#   'LH1_247',
#   'LH1_248',
#   'LH1_249',
#   'LH1_250',
#   'LH1_251',
#   'LH1_252',
#   'LH1_253',
#   'LH1_254',
#   'LH1_255',
#   'LH1_256',
#   'LH1_257',
#   'LH1_258',
#   'LH1_259',
#   'LH1_260',
#   'LH1_343',
#   'LH1_348',
#   'LH1_352',
#   'LH1_353',
#   'LH1_358',
#   'LH1_359',
#   'LH1_381',
#   'LH1_382',
#   'LH1_383',
#   'LH1_384'],
#  'batch1441-1470': ['LH1_385',
#   'LH1_386',
#   'LH1_387',
#   'LH1_388',
#   'LH1_389',
#   'LH1_390',
#   'LH1_391',
#   'LH1_392',
#   'LH1_393',
#   'LH1_394',
#   'LH1_395',
#   'LH1_396',
#   'LH1_397',
#   'LH1_398',
#   'LH1_399',
#   'LH1_400',
#   'LH1_441',
#   'LH1_442',
#   'LH1_443',
#   'LH1_444',
#   'LH1_445',
#   'LH1_446',
#   'LH1_447',
#   'LH1_448',
#   'LH1_449',
#   'LH1_450',
#   'LH1_451',
#   'LH1_452',
#   'LH1_453',
#   'LH1_454'],
#  'batch1471-1500': ['LH1_455',
#   'LH1_456',
#   'LH1_457',
#   'LH1_458',
#   'LH1_459',
#   'LH1_460',
#   'LH1_542',
#   'LH1_543',
#   'LH1_544',
#   'LH1_545',
#   'LH1_546',
#   'LH1_547',
#   'LH1_548',
#   'LH1_549',
#   'LH1_550',
#   'LH1_551',
#   'LH1_552',
#   'LH1_553',
#   'LH1_554',
#   'LH1_555',
#   'LH1_556',
#   'LH1_557',
#   'LH1_558',
#   'LH1_559',
#   'LH1_560',
#   'LH1_581',
#   'LH1_582',
#   'LH1_583',
#   'LH1_584',
#   'LH1_585'],
#  'batch1501-1530': ['LH1_586',
#   'LH1_587',
#   'LH1_588',
#   'LH1_589',
#   'LH1_590',
#   'LH1_591',
#   'LH1_592',
#   'LH1_593',
#   'LH1_594',
#   'LH1_595',
#   'LH1_596',
#   'LH1_597',
#   'LH1_598',
#   'LH1_599',
#   'LH1_600']}

# %% [markdown]
# # SRA-Toolkit

# %%
#use only 1 thread or bad things may happen (Binac will freeze)!

THREADS = 2
logdir = f'{LOGS}/SRAs'

todo = '''
conda activate QC

cd $WS
mkdir -p sra_temp

echo "Processing {BATCH}"
sras=({IDS})
for sra in ${{sras[@]}}; do

    #skip processed files
    if [ -f $RR/${{sra}}_1.fastq.gz ]; then
        echo "$sra already exists. Skipping."
        continue
    fi
    
    if [ -f $RR/${{sra}}.fastq.gz ]; then
        echo "$sra already exists. Skipping."
        continue
    fi
    
    if [ -f $CR/${{sra}}_1.fq.gz ]; then
        echo "$sra already exists. Skipping."
        continue
    fi
    
    if [ -f $CR/${{sra}}.fq.gz ]; then
        echo "$sra already exists. Skipping."
        continue
    fi
    
    #download files
    echo "Prefetch $sra"
    prefetch $sra -O sra_temp --verify yes --max-size 50G

    echo "Convert to fastq $sra"
    fasterq-dump sra_temp/$sra --split-files --outdir $RR --threads 1
    rm -r sra_temp/$sra

    echo "Gzip $sra"
    pigz $RR/${{sra}}_*.fastq
    pigz $RR/${{sra}}.fastq

    
done
echo "All done, check the outputs"
'''

# !mkdir -p $WS/$RR

for batch, ids in batches.items():
    if batch not in ['batch1001-1020']:
        continue
        
    IDS = ' '.join([f"'{l}'" for l in [i for i in ids if i not in bad]])
    binac(ppn=THREADS, time='07:00:00:00', mem=16, name=f'{batch}_SRA', queue='long', 
          logdir=logdir, todo=todo.format(BATCH=batch, IDS=IDS))
# Out:
# 11366442

# %%
# Summarize raw data

df['Status'] = 'Downloaded'
df.loc[df.Run.isin(bad), 'Status'] = 'Broken'

df.to_csv(f'{WS}/Data/MAGs_dataset_complete.csv')

# %%
len(df.loc[df.Status == 'Downloaded'])
# Out:
# 1515

# %% [markdown]
# # Local samples

# %%
#copy assembled contigs for UHO samples and raw data for LH samples

# !mkdir -p $WS/$ASS

for loc in locs:
    if loc.startswith('UHO'):
        continue
        src = f'~/Beeg/PFOWL2-3/Results/MegaHit/{loc}/final.contigs.fa'
        new = f'{WS}/{ASS}/{loc}.fa'
        
        # !cp $src $new
        
    if loc.startswith('LH'):
        for i in range(1,3):
            src = f'/beegfs/work/croth/LH1_metagenomes/Clean_reads/{loc}_{i}.fq.gz'
            new = f'{WS}/{RR}/{loc}_{i}.fastq.gz'
            if os.path.exists(new) or os.path.exists(f'{WS}/{CR}/{loc}_{i}.fq.gz'):
                continue
            
            # !cp $src $new

# %%
locs
# Out:
# ['UHO1',
#  'UHO2',
#  'UHO3',
#  'UHO4',
#  'UHO5',
#  'UHO6',
#  'UHO7',
#  'UHO8',
#  'UHO9',
#  'UHO10',
#  'UHO11',
#  'UHO12',
#  'UHO13',
#  'UHO14',
#  'UHO15',
#  'UHO16',
#  'UHO17',
#  'UHO18',
#  'UHO19',
#  'UHO20',
#  'UHO21',
#  'UHO22',
#  'UHO23',
#  'UHO24',
#  'UHO25',
#  'UHO26',
#  'UHO27',
#  'UHO28',
#  'UHO29',
#  'UHO30',
#  'UHO31',
#  'UHO32',
#  'UHO33',
#  'UHO34',
#  'UHO35',
#  'UHO36',
#  'UHO37',
#  'UHO38',
#  'UHO39',
#  'UHO40',
#  'UHO41',
#  'UHO42',
#  'UHO43',
#  'UHO44',
#  'UHO45',
#  'UHO46',
#  'UHO47',
#  'UHO48',
#  'UHO49',
#  'UHO50',
#  'UHO51',
#  'UHO52',
#  'UHO53',
#  'UHO54',
#  'UHO55',
#  'UHO56',
#  'UHO57',
#  'UHO58',
#  'UHO59',
#  'UHO60',
#  'UHO407',
#  'UHO408',
#  'UHO409',
#  'UHO410',
#  'UHO411',
#  'UHO412',
#  'UHO413',
#  'UHO414',
#  'UHO415',
#  'UHO416',
#  'UHO417',
#  'UHO418',
#  'UHO419',
#  'UHO420',
#  'UHO421',
#  'UHO422',
#  'UHO423',
#  'UHO424',
#  'UHO425',
#  'UHO426',
#  'UHO427',
#  'UHO428',
#  'UHO429',
#  'UHO430',
#  'UHO431',
#  'UHO432',
#  'UHO433',
#  'UHO434',
#  'UHO435',
#  'LH1_241',
#  'LH1_242',
#  'LH1_243',
#  'LH1_244',
#  'LH1_245',
#  'LH1_246',
#  'LH1_247',
#  'LH1_248',
#  'LH1_249',
#  'LH1_250',
#  'LH1_251',
#  'LH1_252',
#  'LH1_253',
#  'LH1_254',
#  'LH1_255',
#  'LH1_256',
#  'LH1_257',
#  'LH1_258',
#  'LH1_259',
#  'LH1_260',
#  'LH1_343',
#  'LH1_348',
#  'LH1_352',
#  'LH1_353',
#  'LH1_358',
#  'LH1_359',
#  'LH1_381',
#  'LH1_382',
#  'LH1_383',
#  'LH1_384',
#  'LH1_385',
#  'LH1_386',
#  'LH1_387',
#  'LH1_388',
#  'LH1_389',
#  'LH1_390',
#  'LH1_391',
#  'LH1_392',
#  'LH1_393',
#  'LH1_394',
#  'LH1_395',
#  'LH1_396',
#  'LH1_397',
#  'LH1_398',
#  'LH1_399',
#  'LH1_400',
#  'LH1_441',
#  'LH1_442',
#  'LH1_443',
#  'LH1_444',
#  'LH1_445',
#  'LH1_446',
#  'LH1_447',
#  'LH1_448',
#  'LH1_449',
#  'LH1_450',
#  'LH1_451',
#  'LH1_452',
#  'LH1_453',
#  'LH1_454',
#  'LH1_455',
#  'LH1_456',
#  'LH1_457',
#  'LH1_458',
#  'LH1_459',
#  'LH1_460',
#  'LH1_542',
#  'LH1_543',
#  'LH1_544',
#  'LH1_545',
#  'LH1_546',
#  'LH1_547',
#  'LH1_548',
#  'LH1_549',
#  'LH1_550',
#  'LH1_551',
#  'LH1_552',
#  'LH1_553',
#  'LH1_554',
#  'LH1_555',
#  'LH1_556',
#  'LH1_557',
#  'LH1_558',
#  'LH1_559',
#  'LH1_560',
#  'LH1_581',
#  'LH1_582',
#  'LH1_583',
#  'LH1_584',
#  'LH1_585',
#  'LH1_586',
#  'LH1_587',
#  'LH1_588',
#  'LH1_589',
#  'LH1_590',
#  'LH1_591',
#  'LH1_592',
#  'LH1_593',
#  'LH1_594',
#  'LH1_595',
#  'LH1_596',
#  'LH1_597',
#  'LH1_598',
#  'LH1_599',
#  'LH1_600']

# %% [markdown]
# # ReadQC and host removal

# %%
#create index

THREADS = 8

todo = '''
conda activate QC

cd {ws}
bowtie2-build {refer} {index} --threads {THREADS}
'''

for ind, ref in REF_GENS.items():
    ws,fa = ref.rsplit('/', 1)
    binac(ppn=THREADS, time='08:00:00', mem=90, name=f'{ind}_Ref', queue='short', 
          logdir=LOGS, todo=todo.format(ws=ws, refer=fa, index=ind, THREADS=THREADS))
# Out:
# 11130446
# 11130447

# %%
#Read QC and host DNA removal

THREADS = 8
logdir = f"{LOGS}/QC"

todo = '''
conda activate QC

echo "Processing {BATCH}"
sras=({IDS})
for name in ${{sras[@]}}; do
    cd $WS
    ref_host={ref_host}
    ind_host={ind_host}
    ref_feed={ref_feed}
    ind_feed={ind_feed}
    preQC=$DATA/FastQC/preQC/$name
    postQC=$DATA/FastQC/postQC/$name
    outdir=$CR/$name
    
    echo
    echo "############################################################"
    echo "Processing $name "
    echo "Check if reads are paired or single" 
    
    if [ -f $RR/${{name}}_1.f*q.gz ]; then
        echo "$name are paired reads."
        RR1=$RR/${{name}}_1.f*q.gz
        RR2=$RR/${{name}}_2.f*q.gz
        CR1=$CR/${{name}}_1.fq.gz
        CR2=$CR/${{name}}_2.fq.gz
    
        #skip processed files
        if [ -f $CR1 ]; then
            echo "$name already cleaned. Skipping."
            continue
        fi
        
        rm -rf $outdir $preQC $postQC $CR1 $CR2
        mkdir -p $preQC $postQC $outdir 
    
        # Fastq report before QC
        echo "Report before QC..."
        fastqc -q -t {THREADS} -o $preQC -f fastq $RR1 $RR2
        
        echo
        echo "Running Trim-Galore for QC"
        echo   
        cd $outdir
        trim_galore --paired $WS/$RR1 $WS/$RR2 -j {THREADS}
    
        # Fastq report after QC
        echo "Report after QC..."
        cd
        cd $WS
        fastqc -q -t {THREADS} -o $postQC -f fastq $outdir/*_val_1.f*q.gz $outdir/*_val_2.f*q.gz
        
        echo
        echo "Removing Host and Feed DNA from reads"
        echo "Mapping reads to the host reference..."
        cd
        cd $ref_host
        bowtie2 -p {THREADS} -x $ind_host -1 $WS/$outdir/*_val_1.f*q.gz -2 $WS/$outdir/*_val_2.f*q.gz \
        --un-conc-gz $WS/$outdir/no_host > $WS/$outdir/host.sam
        echo "Host DNA removed"
        
        echo "Mapping reads to the feed reference..."
        cd
        cd $ref_feed
        bowtie2 -p {THREADS} -x $ind_feed -1 $WS/$outdir/no_host.1 -2 $WS/$outdir/no_host.2 \
        --un-conc-gz $WS/$outdir/no_feed > $WS/$outdir/feed.sam
        echo "Feed DNA removed"
        
        echo
        echo "Move and clean!"
        cd
        cd $WS
        mv $outdir/no_feed.1 $CR1
        mv $outdir/no_feed.2 $CR2
        rm -rf $outdir
    
        #remove processed files
        if [ -f $CR1 ]; then
            echo "Removing raw read since $name successfully cleaned."
            rm $RR1 $RR2
        fi
    fi

    if [ -f $RR/${{name}}.f*q.gz ]; then
        echo "$name are single reads."
        RR1=$RR/${{name}}.f*q.gz
        CR1=$CR/${{name}}.fq.gz
    
        #skip processed files
        if [ -f $CR1 ]; then
            echo "$name already cleaned. Skipping."
            continue
        fi
        
        rm -rf $outdir $preQC $postQC $CR1 $CR2
        mkdir -p $preQC $postQC $outdir 
    
        # Fastq report before QC
        echo "Report before QC..."
        fastqc -q -t {THREADS} -o $preQC -f fastq $RR1
        
        echo
        echo "Running Trim-Galore for QC"
        echo   
        cd $outdir
        trim_galore $WS/$RR1 -j {THREADS}
    
        # Fastq report after QC
        echo "Report after QC..."
        cd
        cd $WS
        fastqc -q -t {THREADS} -o $postQC -f fastq $outdir/*_trimmed.f*q.gz
        
        echo
        echo "Removing Host and Feed DNA from reads"
        echo "Mapping reads to the host reference..."
        cd
        cd $ref_host
        bowtie2 -p {THREADS} -x $ind_host -U $WS/$outdir/*_trimmed.f*q.gz \
        --un-gz $WS/$outdir/no_host > $WS/$outdir/host.sam
        echo "Host DNA removed"
        
        echo "Mapping reads to the feed reference..."
        cd
        cd $ref_feed
        bowtie2 -p {THREADS} -x $ind_feed -U $WS/$outdir/no_host \
        --un-gz $WS/$outdir/no_feed > $WS/$outdir/feed.sam
        echo "Feed DNA removed"
        
        echo
        echo "Move and clean!"
        cd
        cd $WS
        mv $outdir/no_feed $CR1
        rm -rf $outdir
    
        #remove processed files
        if [ -f $CR1 ]; then
            echo "Removing raw read since $name successfully cleaned."
            rm $RR1
        fi
        
    else
        Echo "There is something wrong with that sample (neither paired reads or single read were found)"
        continue
        
    fi
done

echo
echo "############################################################"
echo "###                   All done! Enjoy!                   ###"
echo "### Citations:                                           ###"
echo "### 1. Cutadapt: https://doi.org/10.14806/ej.17.1.200    ###"
echo "### 2. Bowtie: https://doi.org/10.1038/nmeth.1923        ###"
echo "### 3. FastQC (optional):                                ###"
echo "###    https://doi.org/10.1038/nmeth.1923                ###"
echo "### 4. TrimGalore (optional):                            ###"
echo "###    https://github.com/FelixKrueger/TrimGalore        ###"
echo "############################################################"
'''

#get indexes for Host/Feed genomes
inds, refs = [], []
for ind, ref in REF_GENS.items():
    inds.append(ind)
    refs.append(ref.rsplit('/', 1)[0])


#launch samples
for batch, ids in batches.items():
    if batch not in ['batch1001-1020']:
        continue
        
    IDS = ' '.join([f"'{l}'" for l in [i for i in ids if i not in bad]])
            
    binac(ppn=THREADS, time='07:00:00:00', mem=120, name=f'{batch}_QC', queue='long', 
              logdir=logdir, todo=todo.format(BATCH=batch, IDS=IDS, ref_host=refs[0], 
              ind_host=inds[0], ref_feed=refs[1], ind_feed=inds[1], THREADS=THREADS))
# Out:
# 11366477

# %%
#keep output reports 

logs = f"{WS}/{LOGS}/QC"

# !mkdir {WS}/$logs
# !mv *_QC.sh.* {WS}/$logs/

# %%
logs = f"{WS}/{LOGS}/QC"
summ = pd.DataFrame()
summ.index.name='SampleID'
for clean in cleans:
    if clean in [""]:
        continue
    file = [f for f in os.listdir(logs) if f.startswith(f"{clean}_QC.sh.e")][0]
    with open(f'{logs}/{file}') as f:
        txt = f.read().split('Total number of sequences analysed: ')[-1]

        #Get QC stats
        total = float(txt.split('\n')[0])
        bad = float(txt.split('bp): ')[-1].split(' (')[0])
        
        #Get Host/Feed DNA
        no_host = float(txt.split('-\n    ')[1].split(' ')[0])
        no_feed = float(txt.split('-\n    ')[3].split(' ')[0])
        
    summ.loc[clean, ['Total', 'PassedQC', 'NoHost', 'NoFeed']] = [total, total-bad, no_host, no_feed]

#Count %
summ['PassedQC(%)'] = round(100*summ.PassedQC/summ.Total, 3)
summ['Host(%_of_PassedQC)'] = round(100*(summ.PassedQC-summ.NoHost)/summ.PassedQC, 3)
summ['Feed(%_of_PassedQC)'] = round(100*(summ.NoHost-summ.NoFeed)/summ.PassedQC, 3)


#add owner of samples
names = pd.read_csv(f'{WS}/sampleName_clientId.txt', sep='\t', index_col='clientId')
summ['Owner'] = names['Owner']
summ.to_csv(f'{WS}/{DATA}/QC_stats.tsv', sep='\t')
summ
# Out:
#                Total    PassedQC      NoHost      NoFeed  PassedQC(%)
# SampleID
# UHO1      35831867.0  35492845.0  34944907.0  34942341.0       99.054  \
# UHO10     33592806.0  33285677.0  33181082.0  33169124.0       99.086
# UHO100    35201028.0  35184245.0  35159077.0  35156321.0       99.952
# UHO101    35715119.0  35434487.0  35373052.0  35258757.0       99.214
# UHO102    33628784.0  33391514.0  33276130.0  33272830.0       99.294
# ...              ...         ...         ...         ...          ...
# UHO95     34632053.0  34323601.0  34297988.0  34286021.0       99.109
# UHO96     41129500.0  40722799.0  40715886.0  40704007.0       99.011
# UHO97     41883780.0  41511029.0  41507829.0  41505113.0       99.110
# UHO98     40138802.0  39775971.0  32287226.0  32230779.0       99.096
# UHO99     67583716.0  67074144.0  66918180.0  66758326.0       99.246
#
#           Host(%_of_PassedQC)  Feed(%_of_PassedQC)  Owner
# SampleID
# UHO1                    1.544                0.007  Money
# UHO10                   0.314                0.036  Money
# UHO100                  0.072                0.008  Money
# UHO101                  0.173                0.323  Money
# UHO102                  0.346                0.010  Money
# ...                       ...                  ...    ...
# UHO95                   0.075                0.035  Money
# UHO96                   0.017                0.029  Money
# UHO97                   0.008                0.007  Money
# UHO98                  18.827                0.142  Money
# UHO99                   0.233                0.238  Money
#
# [440 rows x 8 columns]

# %% [markdown]
# # Metagenome assemblies Megahit

# %%
THREADS = 12
RAM = 90
logdir = f'{LOGS}/MegaHit'

todo = '''
conda activate qiime2-shotgun-2024.2
echo "Processing {BATCH}"
cd $WS
mkdir -p $MH

sras=({IDS})
for name in ${{sras[@]}}; do
    echo
    echo "############################################################"
    echo "Processing $name "
    
    echo "Check if reads already assembled" 
    if [ -f $ASS/${{name}}.fa ]; then
        echo "$name already assembled. Skipping."
        continue
    fi
    echo "$name is not assembled. Attempting assembly..."
    
    echo "Check if reads are paired or single" 
    if [ -f $CR/${{name}}_1.fq.gz ]; then
        echo "$name are paired reads."
        CR1=$CR/${{name}}_1.fq.gz
        CR2=$CR/${{name}}_2.fq.gz
    
        megahit -1 $CR1 -2 $CR2 -o $MH/$name -t {THREADS} --presets meta-sensitive
    fi
    
    if [ -f $CR/${{name}}.fq.gz ]; then
        echo "$name are single reads."
        CR1=$CR/${{name}}.fq.gz
    
        megahit -r $CR1 -o $MH/$name -t {THREADS} --presets meta-sensitive
    fi

    echo "Checking if assembly created"
    ass=$MH/$name/final.contigs.fa
    if [ -f $ass ]; then
        echo "Moving assembly"
        mv $ass $ASS/${{name}}.fa
    else
        echo "There is something wrong with assembly"
    fi
    rm -r $MH/$name
done

echo
echo "############################################################"
echo "###                   All done! Enjoy!                   ###"
echo "### Citations:                                           ###"
echo "### 1. MegaHit:                                          ###"
echo "###    https://doi.org/10.1093/bioinformatics/btv033     ###"
echo "############################################################"   
'''

#launch samples
for batch, ids in batches.items():
    if batch in ['batch1-30']:
        continue

    IDS = ' '.join(ids)
    binac(ppn=THREADS, time='07:00:00:00', mem=RAM, name=f'{batch}_MH', queue='long', 
          logdir=logdir, todo=todo.format(BATCH=batch, IDS=IDS, THREADS=THREADS))
# Out:
# 11376483
# 11376484
# 11376485
# 11376486
# 11376487
# 11376488
# 11376489
# 11376490
# 11376491
# 11376492
# 11376493
# 11376494
# 11376495
# 11376496
# 11376497
# 11376498
# 11376499
# 11376500
# 11376501
# 11376502
# 11376503
# 11376504
# 11376505
# 11376506
# 11376507
# 11376508
# 11376509
# 11376510
# 11376511
# 11376513
# 11376514
# 11376515
# 11376516
# 11376517
# 11376518
# 11376519
# 11376520
# 11376521
# 11376522
# 11376523
# 11376524
# 11376525
# 11376526
# 11376527
# 11376528
# 11376529
# 11376530
# 11376531
# 11376532
# 11376533

# %%
sras
# Out:
# ['SRR12730711',
#  'SRR12730712',
#  'SRR12730713',
#  'SRR12730714',
#  'SRR12730715',
#  'SRR12730716',
#  'SRR12730718',
#  'SRR12730719',
#  'SRR12730720',
#  'SRR12730721',
#  'SRR12730722',
#  'SRR12730723',
#  'SRR12730724',
#  'SRR12730725',
#  'SRR12730727',
#  'SRR12730728',
#  'SRR12730729',
#  'SRR12730730',
#  'SRR12730731',
#  'SRR12730732',
#  'SRR12730733',
#  'SRR12730734',
#  'SRR12730735',
#  'SRR12730736',
#  'SRR12730737',
#  'SRR12730738',
#  'SRR12730739',
#  'SRR12730740',
#  'SRR12730741',
#  'SRR12730742',
#  'SRR12730744',
#  'SRR12730745',
#  'SRR12730746',
#  'SRR12730747',
#  'SRR12730748',
#  'SRR12730749',
#  'SRR12730750',
#  'SRR8840688',
#  'SRR8840689',
#  'SRR8840690',
#  'SRR8840691',
#  'SRR8840692',
#  'SRR8840693',
#  'SRR8840694',
#  'SRR6323082',
#  'SRR6323083',
#  'SRR6323084',
#  'SRR6323085',
#  'SRR6323086',
#  'SRR6323087',
#  'SRR6323088',
#  'SRR6323089',
#  'SRR6323090',
#  'SRR6323091',
#  'SRR6323092',
#  'SRR6323093',
#  'SRR6323094',
#  'SRR6323095',
#  'SRR6323096',
#  'SRR6323097',
#  'SRR6323098',
#  'SRR6323099',
#  'SRR6323100',
#  'SRR6323101',
#  'SRR6323102',
#  'SRR6323103',
#  'SRR6323104',
#  'SRR6323105',
#  'SRR6323106',
#  'SRR6323107',
#  'SRR6323108',
#  'SRR6323109',
#  'SRR6323110',
#  'SRR6323111',
#  'SRR6323112',
#  'SRR6323113',
#  'SRR6323114',
#  'SRR6323115',
#  'SRR6323116',
#  'SRR6323117',
#  'SRR6323118',
#  'SRR6323119',
#  'SRR6323120',
#  'SRR6323121',
#  'SRR6323122',
#  'SRR6323123',
#  'SRR6323124',
#  'SRR6323125',
#  'SRR6323126',
#  'SRR6323127',
#  'SRR6323128',
#  'SRR6323129',
#  'SRR6323130',
#  'SRR6323131',
#  'SRR6323132',
#  'SRR6323133',
#  'SRR6323134',
#  'SRR6323135',
#  'SRR6323136',
#  'SRR6323137',
#  'SRR6323138',
#  'SRR6323139',
#  'ERR2241694',
#  'ERR2241695',
#  'ERR2241696',
#  'ERR2241697',
#  'ERR2241699',
#  'ERR2241700',
#  'ERR2241701',
#  'ERR2241702',
#  'ERR2241703',
#  'ERR2241704',
#  'ERR2241725',
#  'ERR2241726',
#  'ERR2241727',
#  'ERR2241728',
#  'ERR2241729',
#  'ERR2241730',
#  'ERR2241731',
#  'ERR2241732',
#  'ERR2241733',
#  'ERR2241734',
#  'ERR2241737',
#  'ERR2241738',
#  'ERR2241739',
#  'ERR2241742',
#  'ERR2241743',
#  'ERR2241744',
#  'ERR2241747',
#  'ERR2241748',
#  'ERR2241749',
#  'ERR2241750',
#  'ERR2241752',
#  'ERR2241753',
#  'ERR2241754',
#  'ERR2241755',
#  'ERR2241756',
#  'ERR2241758',
#  'ERR2241759',
#  'ERR2241760',
#  'ERR2241761',
#  'ERR2241762',
#  'ERR2241765',
#  'ERR2241770',
#  'ERR2241783',
#  'ERR2241784',
#  'ERR2241788',
#  'ERR2241790',
#  'ERR2241794',
#  'ERR2241798',
#  'ERR2241799',
#  'ERR2241802',
#  'ERR2241803',
#  'ERR2241805',
#  'ERR2241806',
#  'ERR2241807',
#  'ERR2241808',
#  'ERR2241815',
#  'ERR2241818',
#  'ERR2241819',
#  'ERR2241823',
#  'ERR2241824',
#  'ERR2241828',
#  'ERR2241848',
#  'ERR2241849',
#  'ERR2241851',
#  'ERR2241852',
#  'ERR2241853',
#  'ERR2241854',
#  'ERR2241855',
#  'ERR2241856',
#  'ERR2241857',
#  'ERR2241858',
#  'ERR2241859',
#  'ERR2241860',
#  'ERR2241861',
#  'ERR2241862',
#  'ERR2241863',
#  'ERR2241864',
#  'ERR2241865',
#  'ERR2241866',
#  'ERR2241887',
#  'ERR2241888',
#  'ERR2241889',
#  'ERR2241890',
#  'ERR2241891',
#  'ERR2241892',
#  'ERR2241893',
#  'ERR2241894',
#  'ERR2241895',
#  'ERR2241896',
#  'ERR2241897',
#  'ERR2241898',
#  'ERR2241899',
#  'ERR2241900',
#  'ERR2241901',
#  'ERR2241902',
#  'ERR2241903',
#  'ERR2241904',
#  'ERR2241905',
#  'ERR2241906',
#  'ERR2241907',
#  'ERR2241909',
#  'ERR2241911',
#  'ERR2241913',
#  'ERR2241915',
#  'ERR2241919',
#  'ERR2241921',
#  'ERR2241923',
#  'ERR2241925',
#  'ERR2241927',
#  'ERR2241929',
#  'ERR2241931',
#  'ERR2241933',
#  'ERR2241935',
#  'ERR2241937',
#  'ERR2241939',
#  'ERR2241941',
#  'ERR2241945',
#  'ERR2241950',
#  'ERR2241952',
#  'ERR2241953',
#  'ERR2241954',
#  'ERR2241955',
#  'ERR2241956',
#  'ERR2241957',
#  'ERR2241971',
#  'ERR2241972',
#  'ERR2241977',
#  'ERR2241978',
#  'ERR2241979',
#  'ERR2241980',
#  'ERR2241981',
#  'ERR2241982',
#  'ERR2241983',
#  'ERR2241984',
#  'ERR2241985',
#  'ERR2241986',
#  'ERR2245455',
#  'SRR4096731',
#  'SRR4096732',
#  'SRR4096733',
#  'SRR4096734',
#  'SRR24764565',
#  'SRR24764566',
#  'SRR24764568',
#  'SRR24764569',
#  'SRR24764571',
#  'SRR24764572',
#  'SRR24764574',
#  'SRR24764575',
#  'SRR24764577',
#  'SRR24764580',
#  'SRR24764581',
#  'SRR24764583',
#  'SRR24764564',
#  'SRR24764567',
#  'SRR24764570',
#  'SRR24764576',
#  'SRR24764578',
#  'SRR24764579',
#  'SRR24764582',
#  'ERR864206',
#  'ERR864207',
#  'ERR864208',
#  'ERR864209',
#  'ERR864210',
#  'UHO1',
#  'UHO2',
#  'UHO3',
#  'UHO4',
#  'UHO5',
#  'UHO6',
#  'UHO7',
#  'UHO8',
#  'UHO9',
#  'UHO10',
#  'UHO11',
#  'UHO12',
#  'UHO13',
#  'UHO14',
#  'UHO15',
#  'UHO16',
#  'UHO17',
#  'UHO18',
#  'UHO19',
#  'UHO20',
#  'UHO21',
#  'UHO22',
#  'UHO23',
#  'UHO24',
#  'UHO25',
#  ...]

# %%
#quast -t {THREADS} -o {out}/Quast {out}/final.contigs.fa

# %%
for clean in cleans:
    out = f'{WS}/Results/MegaHit/{clean}'
    # !rm -r $out/intermediate_contigs

# %%
#zip assemblies

logs = f"{LOGS}/MegaHit"

todo = '''
conda activate Work
cd $WS

zip -r MegaHit.zip Results/MegaHit

'''

binac(time='00:48:00:00', mem=16, name=f'MegaHit_zip', queue='short', logdir=logs,
     todo=todo)
# Out:
# 11242915

# %% [markdown]
# ## Metadata

# %%
#manifest file
md = pd.DataFrame()
for sample in cleans:
    md.loc[len(md),['SampleID', 'Path']] = [sample, f'{WS}/{CR}/{sample}_1.fq.gz']
    md.loc[len(md),['SampleID', 'Path']] = [sample, f'{WS}/{CR}/{sample}_2.fq.gz']

mds = np.array_split(md, 44)
for i, df in enumerate(mds):
    df.to_csv(f'{WS}/{DATA}/mudoger_meta_{i}.tsv', sep='\t', index=False, header=False)

# %% [markdown]
# ## Module 1. Preprocess

# %%
# Did not work due to .gz files. Should be unzipped
THREADS = 6
RAM = 120
logdir = f'{LOGS}/MuDoGeR'

todo = '''

cd $WS
mkdir -p Results/MuDoGeR_out
$SOURCE/mudoger_singularity.sh preprocess \
    -s $SOURCE/mudogerV1.sif \
    -o Results/MuDoGeR_out \
    -i Data \
    -d $DB/MuDoGeR_db \
    -m {RAM} \
    -t {THREADS} \
    -f mudoger_meta_{i}.tsv
    
'''

for i in range(44):
    binac(ppn=THREADS, time='07:00:00:00', mem=RAM, name=f'MuDoGeR_{i}', queue='long', 
              logdir=logdir, todo=todo.format(RAM=RAM, THREADS=THREADS, i=i))
# Out:
# 11257792
# 11257793
# 11257794
# 11257795
# 11257796
# 11257797
# 11257798
# 11257799
# 11257800
# 11257801
# 11257802
# 11257803
# 11257804
# 11257805
# 11257806
# 11257807
# 11257808
# 11257809
# 11257810
# 11257811
# 11257812
# 11257813
# 11257814
# 11257815
# 11257816
# 11257817
# 11257818
# 11257819
# 11257820
# 11257821
# 11257822
# 11257823
# 11257824
# 11257825
# 11257826
# 11257827
# 11257828
# 11257829
# 11257830
# KeyboardInterrupt

# %% [markdown]
# # Status

# %%
# !qstat -u ho_graaf20
# Out:
# mgmt02:
#                                                                                   Req'd       Req'd       Elap
# Job ID                  Username    Queue    Jobname          SessID  NDS   TSK   Memory      Time    S   Time
# ----------------------- ----------- -------- ---------------- ------ ----- ------ --------- --------- - ---------
# 11327685                ho_graaf20  smp      BLAST-taxa.sh     28410     1     24    1000gb 720:00:00 R 568:34:03
# 11339514                ho_graaf20  smp      SM_MAGs.sh        39589     1     12     256gb 720:00:00 R 405:57:55
# 11376500                ho_graaf20  long     batch541-570_MH.   8585     1     12      90gb 168:00:00 R 139:24:08
# 11376501                ho_graaf20  long     batch571-600_MH.   8390     1     12      90gb 168:00:00 R 136:26:16
# 11376502                ho_graaf20  long     batch601-630_MH.  31769     1     12      90gb 168:00:00 R 135:51:01
# 11376503                ho_graaf20  long     batch631-660_MH.   1157     1     12      90gb 168:00:00 R 135:48:58
# 11376505                ho_graaf20  long     batch691-720_MH.  12411     1     12      90gb 168:00:00 R 135:39:46
# 11376506                ho_graaf20  long     batch721-750_MH.  19699     1     12      90gb 168:00:00 R 135:37:44
# 11376507                ho_graaf20  long     batch751-780_MH.   8570     1     12      90gb 168:00:00 R 135:36:43
# 11376530                ho_graaf20  long     batch1411-1440_M  15650     1     12      90gb 168:00:00 R 135:19:14

# %%
# !qdel 11366477

# %%
kill =  """
11376394                ho_graaf20  long     batch31-60_MH.sh    --      1     24     120gb 168:00:00 Q       -- 
11376395                ho_graaf20  long     batch61-90_MH.sh    --      1     24     120gb 168:00:00 Q       -- 
11376396                ho_graaf20  long     batch91-120_MH.s    --      1     24     120gb 168:00:00 Q       -- 
11376397                ho_graaf20  long     batch121-150_MH.    --      1     24     120gb 168:00:00 Q       --  
"""

for job in kill.split('\n'):
    ID = job.split(' ')[0]
    # !qdel $ID
# Out:
# usage: qdel [{ -a | -c | -p | -t | -W delay | -m message}] [-b retry_seconds] [<JOBID>[<JOBID>]|'all'|'ALL']...
#        -a -c, -m, -p, -t, and -W are mutually exclusive
# usage: qdel [{ -a | -c | -p | -t | -W delay | -m message}] [-b retry_seconds] [<JOBID>[<JOBID>]|'all'|'ALL']...
#        -a -c, -m, -p, -t, and -W are mutually exclusive

# %%
# !qstat 11366127
# Out:
# qstat: Unknown Job Id Error 11366127.mgmt

# %%
# !qstat
# Out:
# Job ID                    Name             User            Time Use S Queue
# ------------------------- ---------------- --------------- -------- - -----
# 10161757[]                 fb_rna(1)        ho_braat76             0 C short
# 10899958                   h2681L14         hd_wu263               0 H long
# 11089184                   STDIN            tu_zxmle82             0 Q gpu
# 11151211                   Cluster_reads.sh ho_graaf20      3871:14: R smp
# 11153399                   adec_0           st_uws86178     2610:53: R long
# 11153400                   adec_1           st_uws86178     343:09:4 R long
# 11153405                   adec_0           st_uws86178     2607:08: R long
# 11153406                   adec_1           st_uws86178     341:05:3 R long
# 11154060                   ...-tuebingen.de tu_emins01      556:45:2 R gpu
# 11154619                   go_allLambda.sh  st_st176732     1710:25: R long
# 11154620                   go_allLambda.sh  st_st176732     1678:08: R long
# 11154621                   go_allLambda.sh  st_st176732     1715:29: R long
# 11154622                   go_allLambda.sh  st_st176732     1677:51: R long
# 11154623                   go_allLambda.sh  st_st176732     1667:07: R long
# 11154624                   go_allLambda.sh  st_st176732     1634:18: R long
# 11154625                   go_allLambda.sh  st_st176732     1612:37: R long
# 11154626                   go_allLambda.sh  st_st176732     1622:11: R long
# 11154627                   go_allLambda.sh  st_st176732     1086:42: R long
# 11154628                   go_allLambda.sh  st_st176732     1003:49: R long
# 11154629                   go_allLambda.sh  st_st176732     998:38:0 R long
# 11154630                   go_allLambda.sh  st_st176732     1031:48: R long
# 11154631                   go_allLambda.sh  st_st176732     1027:19: R long
# 11154632                   go_allLambda.sh  st_st176732     999:19:1 R long
# 11154633                   go_allLambda.sh  st_st176732     1002:33: R long
# 11154634                   go_allLambda.sh  st_st176732     1000:59: R long
# 11154635                   go_allLambda.sh  st_st176732     976:55:4 R long
# 11154636                   go_allLambda.sh  st_st176732     936:25:0 R long
# 11155238                   ...-Hera_longsml tu_pecsc01      70:43:18 R gpu
# 11155239                   WGSBAC_Test      ho_holzer       385:36:3 R gpu
# 11155243                   fidu-test        tu_pecsc01      69:33:13 R gpu
# 11155487                   T1S1C0B0_fA.sh   hd_bu271        21290:09 R long
# 11225339                   aoc_0            st_uws86178     955:50:2 R short
# 11225340                   aoc_1            st_uws86178     129:08:2 R short
# 11225341                   adec_0           st_uws86178     1058:31: R short
# 11225347                   at8tdp-pa        st_ac127777     43:18:06 R gpu
# 11228344                   pwects           tu_beesc01      280:56:1 R long
# 11228346                   pwects           tu_beesc01      250:39:2 R long
# 11228389                   pwects           tu_beesc01      251:36:4 R long
# 11228437                   npt_out          st_ac141462     524:21:0 R short
# 11228438                   pwects           tu_beesc01      240:03:4 R long
# 11228440                   npt_out          st_ac141462     522:50:0 R short
# 11228441                   npt_out          st_ac141462     523:00:3 R short
# 11228442                   npt_out          st_ac141462     522:52:5 R short
# 11228444                   npt_out          st_ac141462     522:26:4 R short
# 11228445                   ...ediate_python st_st163811     00:00:36 R long
# 11228450                   NS_k2_-0000      tu_pelol01      16620:37 R short
# 11228453                   velocyto         tu_bbcta01      05:38:51 R short
# 11228455                   pwects           tu_beesc01      228:55:2 R long
# 11228459                   pwects           tu_beesc01      58:56:09 R long
# 11228460                   pwects           tu_beesc01      230:53:4 R long
# 11228461                   pwects           tu_beesc01      219:12:2 R long
# 11228462                   pwects           tu_beesc01      219:37:3 R long
# 11228463                   velocyto         tu_bbcta01      05:07:24 R short
# 11228501                   gm_test          hd_kk263        208:23:2 R long
# 11228504                   velocyto         tu_bbcta01      05:04:34 R short
# 11228505                   velocyto         tu_bbcta01      05:20:11 R short
# 11228506                   velocyto         tu_bbcta01      05:06:42 R short
# 11228507                   velocyto         tu_bbcta01      06:02:25 R short
# 11228508                   butane_job.sh    st_uws86178     277:36:0 C short
# 11228509                   butane_job.sh    st_uws86178     276:18:0 C short
# 11228510                   butane_job.sh    st_uws86178     277:32:1 C short
# 11228517                   butane_job.sh    st_uws86178     276:08:0 C short
# 11228520                   butane_job.sh    st_uws86178     277:25:1 C short
# 11228548                   pentane_job.sh   st_uws86178     277:28:4 R short
# 11228549                   pentane_job.sh   st_uws86178     277:18:3 R short
# 11228550                   pentane_job.sh   st_uws86178     277:34:0 R short
# 11228551                   pentane_job.sh   st_uws86178     277:27:4 R short
# 11228552                   pentane_job.sh   st_uws86178     277:33:4 R short
# 11228553                   pentane_job.sh   st_uws86178     277:21:2 R short
# 11228554                   pentane_job.sh   st_uws86178     277:25:3 R short
# 11228555                   pentane_job.sh   st_uws86178     277:27:3 R short
# 11228556                   pentane_job.sh   st_uws86178     277:30:2 R short
# 11228557                   pentane_job.sh   st_uws86178     277:22:5 R short
# 11228558                   pentane_job.sh   st_uws86178     277:23:1 R short
# 11228559                   pentane_job.sh   st_uws86178     277:29:1 R short
# 11228560                   pentane_job.sh   st_uws86178     277:17:2 R short
# 11228561                   pentane_job.sh   st_uws86178     277:33:5 R short
# 11228562                   pentane_job.sh   st_uws86178     277:20:0 R short
# 11228563                   pentane_job.sh   st_uws86178     277:33:5 R short
# 11228564                   pentane_job.sh   st_uws86178     277:29:5 R short
# 11228565                   pentane_job.sh   st_uws86178     277:23:3 R short
# 11228566                   pentane_job.sh   st_uws86178     277:24:4 R short
# 11228567                   pentane_job.sh   st_uws86178     277:20:5 R short
# 11228568                   pentane_job.sh   st_uws86178     145:57:1 R short
# 11228569                   pentane_job.sh   st_uws86178     39:47:22 R short
# 11228570                   pentane_job.sh   st_uws86178     38:53:03 R short
# 11228571                   pentane_job.sh   st_uws86178     39:12:23 R short
# 11228572                   pentane_job.sh   st_uws86178     39:08:39 R short
# 11228573                   pentane_job.sh   st_uws86178     39:08:15 R short
# 11228574                   pentane_job.sh   st_uws86178     38:15:30 R short
# 11228575                   pentane_job.sh   st_uws86178     37:59:36 R short
# 11228576                   pentane_job.sh   st_uws86178     38:02:55 R short
# 11228577                   pentane_job.sh   st_uws86178     38:15:04 R short
# 11228578                   pentane_job.sh   st_uws86178     38:08:28 R short
# 11228579                   pentane_job.sh   st_uws86178     37:55:34 R short
# 11228580                   pentane_job.sh   st_uws86178     38:00:12 R short
# 11228581                   pentane_job.sh   st_uws86178     37:48:55 R short
# 11228582                   pentane_job.sh   st_uws86178     37:12:56 R short
# 11228583                   pentane_job.sh   st_uws86178     37:15:20 R short
# 11228584                   pentane_job.sh   st_uws86178     36:59:25 R short
# 11228585                   pentane_job.sh   st_uws86178     36:30:39 R short
# 11228586                   pentane_job.sh   st_uws86178     36:38:31 R short
# 11228587                   pentane_job.sh   st_uws86178     36:13:18 R short
# 11228588                   pentane_job.sh   st_uws86178     36:12:01 R short
# 11228589                   pentane_job.sh   st_uws86178     04:39:29 R short
# 11228590                   pentane_job.sh   st_uws86178     04:26:27 R short
# 11228591                   pentane_job.sh   st_uws86178     03:40:11 R short
# 11228592                   pentane_job.sh   st_uws86178     03:32:19 R short
# 11228593                   pentane_job.sh   st_uws86178     03:52:26 R short
# 11228594                   pentane_job.sh   st_uws86178     03:50:05 R short
# 11228595                   pentane_job.sh   st_uws86178     03:08:31 R short
# 11228596                   pentane_job.sh   st_uws86178     02:52:57 R short
# 11228597                   pentane_job.sh   st_uws86178     02:58:06 R short
# 11228598                   octane_job.sh    st_uws86178     02:16:03 R short
# 11228599                   octane_job.sh    st_uws86178     02:38:57 R short
# 11228600                   octane_job.sh    st_uws86178     02:34:13 R short
# 11228601                   octane_job.sh    st_uws86178     02:19:18 R short
# 11228602                   octane_job.sh    st_uws86178     02:00:09 R short
# 11228603                   octane_job.sh    st_uws86178     01:20:25 R short
# 11228604                   octane_job.sh    st_uws86178     01:35:50 R short
# 11228605                   octane_job.sh    st_uws86178     00:56:31 R short
# 11228606                   octane_job.sh    st_uws86178     00:11:44 R short
# 11228607                   octane_job.sh    st_uws86178     00:04:17 R short
# 11228608                   octane_job.sh    st_uws86178            0 R short
# 11228609                   octane_job.sh    st_uws86178            0 Q short
# 11228610                   octane_job.sh    st_uws86178            0 Q short
# 11228611                   octane_job.sh    st_uws86178            0 Q short
# 11228612                   octane_job.sh    st_uws86178            0 Q short
# 11228613                   octane_job.sh    st_uws86178            0 Q short
# 11228614                   octane_job.sh    st_uws86178            0 Q short
# 11228615                   octane_job.sh    st_uws86178            0 Q short
# 11228616                   octane_job.sh    st_uws86178            0 Q short
# 11228617                   octane_job.sh    st_uws86178            0 Q short
# 11228618                   octane_job.sh    st_uws86178            0 Q short
# 11228619                   octane_job.sh    st_uws86178            0 Q short
# 11228620                   octane_job.sh    st_uws86178            0 Q short
# 11228621                   octane_job.sh    st_uws86178            0 Q short
# 11228622                   octane_job.sh    st_uws86178            0 Q short
# 11228623                   octane_job.sh    st_uws86178            0 Q short
# 11228624                   octane_job.sh    st_uws86178            0 Q short
# 11228625                   octane_job.sh    st_uws86178            0 Q short
# 11228626                   octane_job.sh    st_uws86178            0 Q short
# 11228627                   octane_job.sh    st_uws86178            0 Q short
# 11228628                   octane_job.sh    st_uws86178            0 Q short
# 11228629                   octane_job.sh    st_uws86178            0 Q short
# 11228630                   octane_job.sh    st_uws86178            0 Q short
# 11228631                   octane_job.sh    st_uws86178            0 Q short
# 11228632                   octane_job.sh    st_uws86178            0 Q short
# 11228633                   octane_job.sh    st_uws86178            0 Q short
# 11228634                   octane_job.sh    st_uws86178            0 Q short
# 11228635                   octane_job.sh    st_uws86178            0 Q short
# 11228636                   octane_job.sh    st_uws86178            0 Q short
# 11228637                   octane_job.sh    st_uws86178            0 Q short
# 11228638                   octane_job.sh    st_uws86178            0 Q short
# 11228639                   octane_job.sh    st_uws86178            0 Q short
# 11228640                   octane_job.sh    st_uws86178            0 Q short
# 11228641                   octane_job.sh    st_uws86178            0 Q short
# 11228642                   octane_job.sh    st_uws86178            0 Q short
# 11228643                   octane_job.sh    st_uws86178            0 Q short
# 11228644                   octane_job.sh    st_uws86178            0 Q short
# 11228645                   octane_job.sh    st_uws86178            0 Q short
# 11228646                   octane_job.sh    st_uws86178            0 Q short
# 11228647                   octane_job.sh    st_uws86178            0 Q short
# 11228648                   hexane_job.sh    st_uws86178            0 Q short
# 11228649                   hexane_job.sh    st_uws86178            0 Q short
# 11228650                   hexane_job.sh    st_uws86178            0 Q short
# 11228651                   hexane_job.sh    st_uws86178            0 Q short
# 11228652                   hexane_job.sh    st_uws86178            0 Q short
# 11228653                   hexane_job.sh    st_uws86178            0 Q short
# 11228654                   hexane_job.sh    st_uws86178            0 Q short
# 11228655                   hexane_job.sh    st_uws86178            0 Q short
# 11228656                   hexane_job.sh    st_uws86178            0 Q short
# 11228657                   hexane_job.sh    st_uws86178            0 Q short
# 11228658                   hexane_job.sh    st_uws86178            0 Q short
# 11228659                   hexane_job.sh    st_uws86178            0 Q short
# 11228660                   hexane_job.sh    st_uws86178            0 Q short
# 11228661                   hexane_job.sh    st_uws86178            0 Q short
# 11228662                   hexane_job.sh    st_uws86178            0 Q short
# 11228663                   hexane_job.sh    st_uws86178            0 Q short
# 11228664                   hexane_job.sh    st_uws86178            0 Q short
# 11228665                   hexane_job.sh    st_uws86178            0 Q short
# 11228666                   hexane_job.sh    st_uws86178            0 Q short
# 11228667                   hexane_job.sh    st_uws86178            0 Q short
# 11228668                   hexane_job.sh    st_uws86178            0 Q short
# 11228669                   hexane_job.sh    st_uws86178            0 Q short
# 11228670                   hexane_job.sh    st_uws86178            0 Q short
# 11228671                   hexane_job.sh    st_uws86178            0 Q short
# 11228672                   hexane_job.sh    st_uws86178            0 Q short
# 11228673                   hexane_job.sh    st_uws86178            0 Q short
# 11228674                   hexane_job.sh    st_uws86178            0 Q short
# 11228675                   hexane_job.sh    st_uws86178            0 Q short
# 11228676                   hexane_job.sh    st_uws86178            0 Q short
# 11228677                   hexane_job.sh    st_uws86178            0 Q short
# 11228678                   hexane_job.sh    st_uws86178            0 Q short
# 11228679                   hexane_job.sh    st_uws86178            0 Q short
# 11228680                   hexane_job.sh    st_uws86178            0 Q short
# 11228681                   hexane_job.sh    st_uws86178            0 Q short
# 11228682                   hexane_job.sh    st_uws86178            0 Q short
# 11228683                   hexane_job.sh    st_uws86178            0 Q short
# 11228684                   hexane_job.sh    st_uws86178            0 Q short
# 11228685                   hexane_job.sh    st_uws86178            0 Q short
# 11228686                   hexane_job.sh    st_uws86178            0 Q short
# 11228687                   hexane_job.sh    st_uws86178            0 Q short
# 11228688                   hexane_job.sh    st_uws86178            0 Q short
# 11228689                   hexane_job.sh    st_uws86178            0 Q short
# 11228690                   hexane_job.sh    st_uws86178            0 Q short
# 11228691                   hexane_job.sh    st_uws86178            0 Q short
# 11228692                   hexane_job.sh    st_uws86178            0 Q short
# 11228693                   hexane_job.sh    st_uws86178            0 Q short
# 11228694                   hexane_job.sh    st_uws86178            0 Q short
# 11228695                   hexane_job.sh    st_uws86178            0 Q short
# 11228696                   hexane_job.sh    st_uws86178            0 Q short
# 11228697                   hexane_job.sh    st_uws86178            0 Q short
# 11228701                   sim_vdw_1        st_st163811     84:24:11 R short
# 11228702                   sim_vdw_3        st_st163811     84:27:00 R short
# 11228703                   sim_vdw_5        st_st163811     84:27:20 R short
# 11228782                   baymodts         st_ac138559     01:52:14 R long
# 11228783                   high_reso        tu_pecaf01      21:06:35 R long
# 11228784                   q2_taxonomy.sh   ho_graaf20             0 Q smp
